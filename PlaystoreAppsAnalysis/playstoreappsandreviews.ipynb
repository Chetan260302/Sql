# %%
import pandas as pd
import numpy as np

# %%
app_data=pd.read_csv(r'C:\Users\HOME\Desktop\Chetan\playstoreliveproj\playstore_apps.csv',index_col='App')
review_data=pd.read_csv(r'C:\Users\HOME\Desktop\Chetan\playstoreliveproj\playstore_reviews.csv')

# %%
app_data.head()
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
#
#                                                      Reviews  Size  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook         159.0   19M
# Coloring book moana                                    967.0   14M
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   87510.0  8.7M
# Sketch - Draw & Paint                               215644.0   25M
# Pixel Draw - Number Art Coloring Book                  967.0  2.8M
#
#                                                       Installs  Type  Price  \
# App
# ...

# %%
app_data.drop_duplicates(keep='first',inplace=True)
review_data.drop_duplicates(keep='first',inplace=True)
app_data.info()
review_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10349 entries, Photo Editor & Candy Camera & Grid & ScrapBook to iHoroscope - 2018 Daily Horoscope & Astrology
# Data columns (total 12 columns):
# Category          10349 non-null object
# Rating            8891 non-null float64
# Reviews           10348 non-null float64
# Size              10349 non-null object
# Installs          10348 non-null float64
# Type              10348 non-null object
# Price             10348 non-null float64
# Content Rating    10348 non-null object
# Genres            10349 non-null object
# Last Updated      10348 non-null object
# Current Ver       10341 non-null object
# Android Ver       10346 non-null object
# dtypes: float64(4), object(8)
# memory usage: 1.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30679 entries, 0 to 64236
# Data columns (total 5 columns):
# App                       30679 non-null object
# Translated_Review         29692 non-null object
# ...

# %%
print(app_data.shape)
print(review_data.shape)
# Out:
# (10349, 12)
# (30679, 5)

# %%
app_data.dropna(inplace=True)
review_data.dropna(inplace=True)

# %%
app_data
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# Paper flowers instructions                               ART_AND_DESIGN
# Smoke Effect Photo Maker - Smoke Editor                  ART_AND_DESIGN
# Infinite Painter                                         ART_AND_DESIGN
# Garden Coloring Book                                     ART_AND_DESIGN
# Kids Paint Free - Drawing Fun                            ART_AND_DESIGN
# Text on Photo - Fonteee                                  ART_AND_DESIGN
# Name Art Photo Editor - Focus n Filters                  ART_AND_DESIGN
# ...

# %%
print(app_data['Category'].unique())
print(app_data['Rating'].unique())
print(app_data[app_data['Category']=='1.9'])
# Out:
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION']
# [4.1 3.9 4.7 4.5 4.3 4.4 3.8 4.2 4.6 4.  4.8 4.9 3.6 3.7 3.2 3.3 3.4 3.5
#  3.1 5.  2.6 3.  1.9 2.5 2.8 2.7 1.  2.9 2.3 2.2 1.7 2.  1.8 2.4 1.6 2.1
#  1.4 1.5 1.2]
# Empty DataFrame
# Columns: [Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
app_data.to_csv(r'C:\Users\HOME\Desktop\Chetan\playstoreliveproj\app_data_cleaned.csv')

# %%
review_data.to_csv(r'C:\Users\HOME\Desktop\Chetan\playstoreliveproj\review_data.csv')
